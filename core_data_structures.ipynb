# %%
import pandas as pd

# %%
s1 = pd.Series([76, 65, 49, 86, 79, 83])

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
print(s1)
# Out:
# 0    76
# 1    65
# 2    49
# 3    86
# 4    79
# 5    83
# dtype: int64

# %%
s2 = pd.Series([76, 65, 49, 86, 79, 83], index = ["mandar","abhi","sau","soham","meet","ganu"])

# %%
print(s2)
# Out:
# mandar    76
# abhi      65
# sau       49
# soham     86
# meet      79
# ganu      83
# dtype: int64

# %%
s2["sau"]
# Out:
# np.int64(49)

# %%
s2["soham"]
# Out:
# np.int64(86)

# %%
data = {
    "Name": ["mandar","abhi","sau","soham","meet","ganu"],
    "City": ["thane", "aeroli", "delhi", "pune", "chennai", "surat"],
    "Age": [20, 26, 24, 21, 22, 19]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      Name     City  Age
# 0  mandar    thane   20
# 1    abhi   aeroli   26
# 2     sau    delhi   24
# 3   soham     pune   21
# 4    meet  chennai   22
# 5    ganu    surat   19

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.columns
# Out:
# Index(['Name', 'City', 'Age'], dtype='object')
